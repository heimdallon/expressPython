# %%
import math
def main():
  print("los valores se esablecen con las letras a,b,c.")
  print("considere a como el valor de x2, b valor en x y c valor sin incognita")
  a= int ( input("ingresa el valor para a: "))
  b= int (input("ingrese el valor para b: "))
  c= int ( input("ingrese el valor para c: "))

  discriminante = (b**2)-4*a*c
  print(discriminante,"error el discriminante tiene que se positivo")
  main()

  if discriminante>0:
     x1=-b+math.sqrt(discriminante)/2*a
     x2=-b-math.sqrt(discriminante)/2*a
     print("x1=  ",x1)
     print("x2=  ",x2)
     main()

# %% [markdown]
# Escribir un programa que calcule las ra´ıces de
# ax2 + bx + c = 0
